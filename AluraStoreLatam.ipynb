# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolb21/AluraStoreLatam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
ingreso_total_1= tienda['Precio'].sum()
ingreso_total_2= tienda2['Precio'].sum()
ingreso_total_3= tienda3['Precio'].sum()
ingreso_total_4= tienda4['Precio'].sum()


print(f"El ingreso total de la tienda 1 es: {ingreso_total_1:.2f}")
print(f"El ingreso total de la tienda 2 es: {ingreso_total_2:.2f}")
print(f"El ingreso total de la tienda 3 es: {ingreso_total_3:.2f}")
print(f"El ingreso total de la tienda 4 es: {ingreso_total_4:.2f}")
# Out:
# El ingreso total de la tienda 1 es: 1150880400.00
# El ingreso total de la tienda 2 es: 1116343500.00
# El ingreso total de la tienda 3 es: 1098019600.00
# El ingreso total de la tienda 4 es: 1038375700.00

# %%
import matplotlib.pyplot as plt

# %%
## SE MOSTRARA UN INGRESO TOTAL DE LA SUMATORIA DE TODAS LAS TIENDAS Y AHI SE MOSTRARA QUE PORCENTAJE DE ESE TOTAL REPRESENTA CADA TIENDA

nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingreso_total_1, ingreso_total_2, ingreso_total_3, ingreso_total_4]

plt.figure(figsize=(4, 4))
plt.pie(ingresos, labels=nombres_tiendas, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.title('Porcentaje del ingreso TOTAL del negocio por tienda')
plt.axis('equal') # Para asegurar que el círculo sea un círculo
plt.show()

# %%
import matplotlib.ticker as mticker

df_ingresos_comparacion = pd.DataFrame({'Ingresos': ingresos}, index=nombres_tiendas)

ax = df_ingresos_comparacion.plot(kind='bar', figsize=(6, 6), ylabel='Ingresos totales', title='Comparación de Ingresos Totales por Tienda', legend=False,color='red')

# Formatear el eje Y para mostrar los valores en millones
formatter = mticker.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M')
ax.yaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
venta_categoria_1 = tienda['Categoría del Producto'].value_counts()
venta_categoria_2 = tienda2['Categoría del Producto'].value_counts()
venta_categoria_3 = tienda3['Categoría del Producto'].value_counts()
venta_categoria_4 = tienda4['Categoría del Producto'].value_counts()

# %%
display(venta_categoria_1)
display(venta_categoria_2)
display(venta_categoria_3)
display(venta_categoria_4)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
# Categoría del Producto
# ...

# %%
df_ventas_comparacion = pd.DataFrame({'Tienda 1': venta_categoria_1, 'Tienda 2': venta_categoria_2,'Tienda 3': venta_categoria_3, 'Tienda 4': venta_categoria_4}).fillna(0)

ax = df_ventas_comparacion.plot(kind='barh', figsize=(10, 6), xlabel='Cantidad', ylabel='Categoría del Producto', title='Ventas por Categoría', legend=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio_1= tienda['Calificación'].mean()
calificacion_promedio_2= tienda2['Calificación'].mean()
calificacion_promedio_3= tienda3['Calificación'].mean()
calificacion_promedio_4= tienda4['Calificación'].mean()

# %%
print(f"La calificacion promedio de la tienda 1  es: {calificacion_promedio_1:.2f}.")
print(f"La calificacion promedio de la tienda 2  es: {calificacion_promedio_2:.2f}.")
print(f"La calificacion promedio de la tienda 3  es: {calificacion_promedio_3:.2f}.")
print(f"La calificacion promedio de la tienda 4  es: {calificacion_promedio_4:.2f}.")
# Out:
# La calificacion promedio de la tienda 1  es: 3.98.
# La calificacion promedio de la tienda 2  es: 4.04.
# La calificacion promedio de la tienda 3  es: 4.05.
# La calificacion promedio de la tienda 4  es: 4.00.

# %%
calificacion = [calificacion_promedio_1, calificacion_promedio_2, calificacion_promedio_3, calificacion_promedio_4]

df_calificacion_comparacion = pd.DataFrame({'Calificacion': calificacion}, index=nombres_tiendas)

ax = df_calificacion_comparacion.plot(kind='bar', figsize=(6, 6), ylabel='Calificacion', title='Calificacion promedio por Tienda', legend=False)


plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
cant_productos = tienda['Producto'].value_counts()
producto_mayor_ventas = cant_productos.idxmax()
ventas_maximas = cant_productos.max()

cant_productos2 = tienda2['Producto'].value_counts()
producto_mayor_ventas2 = cant_productos2.idxmax()
ventas_maximas2 = cant_productos2.max()

cant_productos3 = tienda3['Producto'].value_counts()
producto_mayor_ventas3 = cant_productos3.idxmax()
ventas_maximas3 = cant_productos3.max()

cant_productos4 = tienda4['Producto'].value_counts()
producto_mayor_ventas4 = cant_productos4.idxmax()
ventas_maximas4 = cant_productos4.max()

print(f"El producto con mayores ventas de la tienda 1 es: '{producto_mayor_ventas}' con {ventas_maximas} unidades vendidas.")
print(f"El producto con mayores ventas de la tienda 2 es: '{producto_mayor_ventas2}' con {ventas_maximas2} unidades vendidas.")
print(f"El producto con mayores ventas de la tienda 3 es: '{producto_mayor_ventas3}' con {ventas_maximas3} unidades vendidas.")
print(f"El producto con mayores ventas de la tienda 4 es: '{producto_mayor_ventas4}' con {ventas_maximas4} unidades vendidas.")
# Out:
# El producto con mayores ventas de la tienda 1 es: 'Microondas' con 60 unidades vendidas.
# El producto con mayores ventas de la tienda 2 es: 'Iniciando en programación' con 65 unidades vendidas.
# El producto con mayores ventas de la tienda 3 es: 'Kit de bancas' con 57 unidades vendidas.
# El producto con mayores ventas de la tienda 4 es: 'Cama box' con 62 unidades vendidas.

# %%
producto_menor_ventas = cant_productos.idxmin()
ventas_minimas = cant_productos.min()

producto_menor_ventas2 = cant_productos2.idxmin()
ventas_minimas2 = cant_productos2.min()

producto_menor_ventas3 = cant_productos3.idxmin()
ventas_minimas3 = cant_productos3.min()

producto_menor_ventas4 = cant_productos4.idxmin()
ventas_minimas4 = cant_productos4.min()

print(f"El producto con menores ventas de la tienda 1 es: '{producto_menor_ventas}' con {ventas_minimas} unidades vendidas.")
print(f"El producto con menores ventas de la tienda 2 es: '{producto_menor_ventas2}' con {ventas_minimas2} unidades vendidas.")
print(f"El producto con menores ventas de la tienda 3 es: '{producto_menor_ventas3}' con {ventas_minimas3} unidades vendidas.")
print(f"El producto con menores ventas de la tienda 4 es: '{producto_menor_ventas4}' con {ventas_minimas4} unidades vendidas.")
# Out:
# El producto con menores ventas de la tienda 1 es: 'Auriculares con micrófono' con 33 unidades vendidas.
# El producto con menores ventas de la tienda 2 es: 'Juego de mesa' con 32 unidades vendidas.
# El producto con menores ventas de la tienda 3 es: 'Bloques de construcción' con 35 unidades vendidas.
# El producto con menores ventas de la tienda 4 es: 'Guitarra eléctrica' con 33 unidades vendidas.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio = tienda['Costo de envío'].mean()
costo_envio2 = tienda2['Costo de envío'].mean()
costo_envio3 = tienda3['Costo de envío'].mean()
costo_envio4 = tienda4['Costo de envío'].mean()

print(f"El costo de envio promedio de la tienda 1 es: {costo_envio:.2f}")
print(f"El costo de envio promedio de la tienda 2 es: {costo_envio2:.2f}")
print(f"El costo de envio promedio de la tienda 3 es: {costo_envio3:.2f}")
print(f"El costo de envio promedio de la tienda 4 es: {costo_envio4:.2f}")
# Out:
# El costo de envio promedio de la tienda 1 es: 26018.61
# El costo de envio promedio de la tienda 2 es: 25216.24
# El costo de envio promedio de la tienda 3 es: 24805.68
# El costo de envio promedio de la tienda 4 es: 23459.46

# %%
costo_envio_total = [costo_envio, costo_envio2, costo_envio3, costo_envio4]

df_costo_envio_total_comparacion= pd.DataFrame({'Costo envio': costo_envio_total}, index=nombres_tiendas)

ax = df_costo_envio_total_comparacion.plot(kind='bar', figsize=(6, 6), ylabel='Costo envio', title='Costo de envio promedio', legend=False)

plt.show()

# %% [markdown]
# #**INFORME FINAL**
#
#
# ---
# El objetivo de este analisis es mostrarle al Sr. Juan las debilidades y fortalezas de cada tienda, dandole una conclusion de que tienda debe vender o que caracteristicas deberia mejorar en esa tienda.
#
#
#
# ---
#
#
#
# ## **Resumen de lo anteriormente calculado**
#
#
# Si analizamos los ingresos de la tienda 1 es la que mas ingresos tuvo sobre la tienda 2 por un monto de 34.539.900. Siendo la tienda 4 la que peores ingresos tuvo.
#
# ![ingresos por tienda.png](data:image/png;base64,...)
#
# Luego, se puede notar que los productos por categoria en cada tienda es muy similar, es decir no hay una tienda que venda muchos mas productos de una categoria que otra y viseversa.
#
# ![ventacategoria.png](data:image/png;base64,...)
#
# Otro dato importante de analizar es el promedio de calificaciones recibidas por los clientes, la tienda 3 es la que mejor esta valorada por los clientes siendo la tienda 1 la peor valorizada.
#
# ![calificacionpromedio.png](data:image/png;base64,...)
#
# Ademas, si visualizamos el costo de envio de la tienda 1 veremos que es el mas caro. Siendo el de la tienda 4 el mas barato.
#
#
# ![costodeenvio.png](data:image/png;base64,...)
#
# # **Conclusion:**
#
#
# > Aunque la tienda 1 presenta el mayor ingreso, tambien muestra la calificacion promedio mas bajo y el mayor costo de envio. Estos factores pueden indicar a futuro un mayor riesgo de perdida de clientes ante la competencia en un largo plazo, por lo que se recomienda la venta. Si no se deseara vender se recomendaria tratar de realizar capacitaciones al personal para que de esta manera pueda mejorar la atencion al publico y asi mejorar la valorizacion del cliente, ademas, sugiero que se optimicen los gastos de envio, tal vez utilizando otro tipo de medio de envio, o tal vez tardar un tiempo mayor en el envio pero disminuyendo costos.
# Tomaria como referencia la Tienda 3 la cual tiene la mejor calificacion, ingresos competitivos y un envio mas economico que la tienda 1 y 2.
